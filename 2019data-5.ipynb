# %% [raw]
# ### 2019 Data Analysis

# %%
import pandas as pd
df = pd.read_csv('preprocessed_data.csv')
df.head(3)
# Out:
#    listing_id         id        date  reviewer_id  \
# 0       13913  451955791  2019-05-12     58728173
# 1       13913  467269212  2019-06-10      2291517
# 2       13913  538005731  2019-09-29      7253695
#
#                                             comments  SentenceLength  Year  \
# 0  alinas place is cosy convenient and full of ec...             268  2019
# 1  alina was very quick to respond thoughtful and...              91  2019
# 2  alina is an amazing host who welcomed me warml...             152  2019
#
#   detect                                     comments_token  \
# 0     en  ['alinas', 'place', 'cosy', 'convenient', 'ful...
# 1     en  ['alina', 'quick', 'respond', 'thoughtful', 'a...
# 2     en  ['alina', 'amazing', 'host', 'welcomed', 'warm...
#
#                                      comments_string
# 0  alinas place cosy convenient full eclectic art...
# 1  alina quick respond thoughtful accommodating d...
# 2  alina amazing host welcomed warmly always talk...

# %%
data_2019 = df[df["Year"]==2019]
data_2019.to_csv('data_2019.csv', index=False)

# %%
df_2019= pd.read_csv('data_2019.csv')
df_2019.head()
# Out:
#    listing_id         id        date  reviewer_id  \
# 0       13913  451955791  2019-05-12     58728173
# 1       13913  467269212  2019-06-10      2291517
# 2       13913  538005731  2019-09-29      7253695
# 3       13913  539957261  2019-10-02     45592945
# 4       13913  543287825  2019-10-07     28531625
#
#                                             comments  SentenceLength  Year  \
# 0  alinas place is cosy convenient and full of ec...             268  2019
# 1  alina was very quick to respond thoughtful and...              91  2019
# 2  alina is an amazing host who welcomed me warml...             152  2019
# 3  alina is a very relaxed and friendly host who ...             259  2019
# 4  felt at home - alina is an excellent host - ve...             114  2019
#
#   detect                                     comments_token  \
# 0     en  ['alinas', 'place', 'cosy', 'convenient', 'ful...
# 1     en  ['alina', 'quick', 'respond', 'thoughtful', 'a...
# ...

# %%
len(df_2019)
# Out:
# 211692

# %%
## Analysis 2019 ##

# %%
# Create list of all words
all_words_19 = ' '.join([str(word) for word in df_2019['comments_string']])

# %%
# Tokenise all words 
import nltk
tokenized_words_19 = nltk.tokenize.word_tokenize(all_words_19)

# %%
# Frequency dstribution for all words 2019
import nltk
from nltk.probability import FreqDist
fdist_19 = FreqDist(tokenized_words_19)

# %%
df_2019.head(3)
# Out:
#    listing_id         id        date  reviewer_id  \
# 0       13913  451955791  2019-05-12     58728173
# 1       13913  467269212  2019-06-10      2291517
# 2       13913  538005731  2019-09-29      7253695
#
#                                             comments  SentenceLength  Year  \
# 0  alinas place is cosy convenient and full of ec...             268  2019
# 1  alina was very quick to respond thoughtful and...              91  2019
# 2  alina is an amazing host who welcomed me warml...             152  2019
#
#   detect                                     comments_token  \
# 0     en  ['alinas', 'place', 'cosy', 'convenient', 'ful...
# 1     en  ['alina', 'quick', 'respond', 'thoughtful', 'a...
# 2     en  ['alina', 'amazing', 'host', 'welcomed', 'warm...
#
#                                      comments_string
# 0  alinas place cosy convenient full eclectic art...
# 1  alina quick respond thoughtful accommodating d...
# 2  alina amazing host welcomed warmly always talk...

# %%
df_2019.dtypes
# Out:
# listing_id          int64
# id                  int64
# date               object
# reviewer_id         int64
# comments           object
# SentenceLength      int64
# Year                int64
# detect             object
# comments_token     object
# comments_string    object
# dtype: object

# %%
# Lemmanisation 

nltk.download('wordnet')
nltk.download('omw-1.4')

from nltk.stem import WordNetLemmatizer

wordnet_lem = WordNetLemmatizer()

df_2019['comments_string'] = df_2019['comments_string'].astype(str)
df_2019['comments_string_lem'] = df_2019['comments_string'].apply(wordnet_lem.lemmatize)
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/lucywalker/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     /Users/lucywalker/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %%
df_2019.head()
# Out:
#    listing_id         id        date  reviewer_id  \
# 0       13913  451955791  2019-05-12     58728173
# 1       13913  467269212  2019-06-10      2291517
# 2       13913  538005731  2019-09-29      7253695
# 3       13913  539957261  2019-10-02     45592945
# 4       13913  543287825  2019-10-07     28531625
#
#                                             comments  SentenceLength  Year  \
# 0  alinas place is cosy convenient and full of ec...             268  2019
# 1  alina was very quick to respond thoughtful and...              91  2019
# 2  alina is an amazing host who welcomed me warml...             152  2019
# 3  alina is a very relaxed and friendly host who ...             259  2019
# 4  felt at home - alina is an excellent host - ve...             114  2019
#
#   detect                                     comments_token  \
# 0     en  ['alinas', 'place', 'cosy', 'convenient', 'ful...
# 1     en  ['alina', 'quick', 'respond', 'thoughtful', 'a...
# ...

# %%
# Word Cloud 2019

all_words_lem_19 = ' '.join([word for word in df_2019['comments_string_lem']])

# %matplotlib inline
import matplotlib.pyplot as plt
from wordcloud import WordCloud

wordcloud = WordCloud(width=600, 
                     height=400, 
                     random_state=2,
                     background_color='white',
                     max_font_size=100).generate(all_words_lem_19)

plt.figure(figsize=(10, 7))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off');

# %%
## Add polarity scores to df_2019 - sentiment analysis 

from textblob import TextBlob

df_2019['polarity'] = df_2019['comments'].apply(lambda x: TextBlob(x).polarity)
df_2019.head(3)
# Out:
#    listing_id         id        date  reviewer_id  \
# 0       13913  451955791  2019-05-12     58728173
# 1       13913  467269212  2019-06-10      2291517
# 2       13913  538005731  2019-09-29      7253695
#
#                                             comments  SentenceLength  Year  \
# 0  alinas place is cosy convenient and full of ec...             268  2019
# 1  alina was very quick to respond thoughtful and...              91  2019
# 2  alina is an amazing host who welcomed me warml...             152  2019
#
#   detect                                     comments_token  \
# 0     en  ['alinas', 'place', 'cosy', 'convenient', 'ful...
# 1     en  ['alina', 'quick', 'respond', 'thoughtful', 'a...
# 2     en  ['alina', 'amazing', 'host', 'welcomed', 'warm...
#
#                                      comments_string  \
# 0  alinas place cosy convenient full eclectic art...
# 1  alina quick respond thoughtful accommodating d...
# ...

# %%
df_2019["polarity"].mean()
# Out:
# 0.41234444613900817

# %%
# Frequency Distributions

nltk.download('punkt')
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist

words = nltk.word_tokenize(all_words_lem_19)
fd_19 = FreqDist(words)

# Obtain top 10 words
top_10_19 = fd_19.most_common(10)

# Create pandas series to make plotting easier
fdist_19 = pd.Series(dict(top_10_19))

import seaborn as sns
sns.set_theme(style="ticks")

sns.barplot(y=fdist_19.index, x=fdist_19.values, color='blue');
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/lucywalker/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
print(top_10_19)
# Out:
# [('great', 111915), ('host', 102515), ('place', 97604), ('location', 77155), ('clean', 68457), ('london', 61922), ('nice', 50865), ('room', 48055), ('good', 41981), ('recommend', 41878)]

# %%
#create df for frequency
df_19_freq = pd.DataFrame({'col':top_10_19})
print (df_19_freq)
# Out:
#                   col
# 0     (great, 111915)
# 1      (host, 102515)
# 2      (place, 97604)
# 3   (location, 77155)
# 4      (clean, 68457)
# 5     (london, 61922)
# 6       (nice, 50865)
# 7       (room, 48055)
# 8       (good, 41981)
# 9  (recommend, 41878)

# %%
df_2019[df_2019['polarity']>0].count()
# Out:
# listing_id             207577
# id                     207577
# date                   207577
# reviewer_id            207577
# comments               207577
# SentenceLength         207577
# Year                   207577
# detect                 207577
# comments_token         207577
# comments_string        207577
# comments_string_lem    207577
# polarity               207577
# dtype: int64

# %%
df_2019[df_2019['polarity']<0].count()
# Out:
# listing_id             2644
# id                     2644
# date                   2644
# reviewer_id            2644
# comments               2644
# SentenceLength         2644
# Year                   2644
# detect                 2644
# comments_token         2644
# comments_string        2644
# comments_string_lem    2644
# polarity               2644
# dtype: int64

# %%
df_2019[df_2019['polarity']==0].count()
# Out:
# listing_id             1471
# id                     1471
# date                   1471
# reviewer_id            1471
# comments               1471
# SentenceLength         1471
# Year                   1471
# detect                 1471
# comments_token         1471
# comments_string        1471
# comments_string_lem    1471
# polarity               1471
# dtype: int64

# %%
import matplotlib.pyplot as plt
 
data = [207586, 2638, 1476]
label = ['Positive', 'Negative', 'Neutral']

labels = [r'Positive (98.1 %)', r'Negative (1.2 %)', r'Neutral (0.7 %)']
colours = ['blue', 'red', 'green']

plt.figure(figsize=(10,10))
plt.pie(data,labels=None, colors = colours, startangle=90)
plt.title('Sentiment Analysis 2019')
plt.legend(labels, loc="best")


plt.axis('equal')
plt.show()

# %%
Histogram_19 = plt.hist(df_2019["polarity"], bins=20, color='blue', edgecolor='k', alpha=0.65)
plt.axvline(df_2019["polarity"].mean(), color='k', linestyle='dashed', linewidth=1)

min_ylim, max_ylim = plt.ylim()
plt.text(df_2019["polarity"].mean()*1.1, max_ylim*0.9, 'Mean: {:.3f}'.format(df_2019["polarity"].mean()))

plt.xlabel("Polarity")
plt.ylabel("Count")
plt.title = ('Polarity Scores 2019')

# %%
## Add Subjectivity scores to df_2019  

sub = lambda x: TextBlob(x).sentiment.subjectivity
df_2019['subjectivity'] = df_2019['comments'].apply(sub)
df_2019.sample(3)
# Out:
#         listing_id         id        date  reviewer_id  \
# 66279     15629760  503732506  2019-08-06     66097559
# 37426      8728789  481734378  2019-07-05    268629547
# 134725    27081316  469887867  2019-06-15    263151262
#
#                                                  comments  SentenceLength  \
# 66279   megans place is terrific: great location wonde...             105
# 37426   amazing stay and lovely hosts would recommend ...             108
# 134725  thank u very much! we will come back at this h...              56
#
#         Year detect                                     comments_token  \
# 66279   2019     en  ['megans', 'place', 'terrific', 'great', 'loca...
# 37426   2019     en  ['amazing', 'lovely', 'hosts', 'recommend', 'a...
# 134725  2019     en              ['u', 'much', 'come', 'back', 'home']
#
#                                           comments_string  \
# 66279   megans place terrific great location wonderful...
# ...

# %%
# Subjectivity Histogram

plt.figure(figsize=(10,5))
sns.distplot(df_2019['subjectivity'], hist=True, kde=True,
bins=int(30), color = 'darkblue',
hist_kws={'edgecolor':'black'},
kde_kws={'linewidth': 4})
plt.xlim([-0.001,1.001])
plt.xlabel('Subjectivity', fontsize=13)
plt.ylabel('Frequency', fontsize=13)
# Out:
# /Users/lucywalker/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0, 0.5, 'Frequency')

# %%
df_2019["subjectivity"].mean()
# Out:
# 0.6290210952882163

# %%
# Forming N Grams function

import re
from nltk.util import ngrams
from collections import Counter
import csv
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt
from nltk.corpus import stopwords
import nltk

def documentNgrams(documents, size):
    ngrams_all = []
    for document in documents:
        tokens = document.split()
        if len(tokens) <= size:
            continue
        else:
            output = list(ngrams(tokens, size))
        for ngram in output:
            ngrams_all.append(" ".join(ngram))
    cnt_ngram = Counter()
    for word in ngrams_all:
        cnt_ngram[word] += 1
    df = pd.DataFrame.from_dict(cnt_ngram, orient='index').reset_index()
    df = df.rename(columns={'index':'words', 0:'count'})
    df = df.sort_values(by='count', ascending=False)
    df = df.head(15)
    df = df.sort_values(by='count')
    return(df)

# %%
# Plotting N Grams function

def plotNgrams(documents):
    unigrams = documentNgrams(documents, 1)
    bigrams = documentNgrams(documents, 2)
    trigrams = documentNgrams(documents, 3)
    
    # Set plot figure size
    fig = plt.figure(figsize = (20, 7))
    plt.subplots_adjust(wspace=.5)

    ax = fig.add_subplot(131)
    ax.barh(np.arange(len(unigrams['words'])), unigrams['count'], align='center', alpha=.5)
    ax.set_title('Unigrams')
    plt.yticks(np.arange(len(unigrams['words'])), unigrams['words'])
    plt.xlabel('Count')

    ax2 = fig.add_subplot(132)
    ax2.barh(np.arange(len(bigrams['words'])), bigrams['count'], align='center', alpha=.5)
    ax2.set_title('Bigrams')
    plt.yticks(np.arange(len(bigrams['words'])), bigrams['words'])
    plt.xlabel('Count')

    ax3 = fig.add_subplot(133)
    ax3.barh(np.arange(len(trigrams['words'])), trigrams['count'], align='center', alpha=.5)
    ax3.set_title('Trigrams')
    plt.yticks(np.arange(len(trigrams['words'])), trigrams['words'])
    plt.xlabel('Count')

    plt.show()
    
plotNgrams
# Out:
# <function __main__.plotNgrams(documents)>

# %%
def textTrends(documents):
    plotNgrams(documents)

# %%
# Determining Sentiment

posReviews = df_2019[df_2019['polarity'] > 0]
negReviews = df_2019[df_2019['polarity'] < 0]

# %%
# Bigrams of positive reviews

textTrends(posReviews['comments_string_lem'])

# %%
# Bigrams of negative reviews

textTrends(negReviews['comments_string_lem'])
